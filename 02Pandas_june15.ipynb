# %% [markdown]
# # Pandas

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 1D data structures in pandas

# %%
# Pandas Series

# %%
# Creating Pandas Series

# %%
import pandas as pd

# %%
s = pd.Series([10,20,30])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s1 = pd.Series([20,60,80])

# %%
s1
# Out:
# 0    20
# 1    60
# 2    80
# dtype: int64

# %%
# With Custom Index

# %%
s = pd.Series([10,20,30],index=['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s2 = pd.Series(["shivam",18,95],index=["name","age","marks"])

# %%
s2
# Out:
# name     shivam
# age          18
# marks        95
# dtype: object

# %%
# From Dictionary

# %%
data = {'Name':"Rahul",'Age':25,"Marks":90}

# %%
s = pd.Series(data)

# %%
s
# Out:
# Name     Rahul
# Age         25
# Marks       90
# dtype: object

# %%
data = {"Name":"shivam","subject":"Math","Marks":94}

# %%
s = pd.Series(data)

# %%
s
# Out:
# Name       shivam
# subject      Math
# Marks          94
# dtype: object

# %%
s = pd.Series(5,index=[0,1,2,3])

# %%
s
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %%
s = pd.Series(10, index =[0,1,2,3,4,5,6,7,8])

# %%
s
# Out:
# 0    10
# 1    10
# 2    10
# 3    10
# 4    10
# 5    10
# 6    10
# 7    10
# 8    10
# dtype: int64

# %%
# Attributes

# %%
s = pd.Series([10,20,30],index=['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s.values
# Out:
# array([10, 20, 30])

# %%
s.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.shape
# Out:
# (3,)

# %%
# Data Manipulation

# %%
s = pd.Series([1,2,3,4])

# %%
print(s*3)
# Out:
# 0     3
# 1     6
# 2     9
# 3    12
# dtype: int64

# %%
# Handling Missing values

# %%
s = pd.Series([1,None,3])

# %%
s
# Out:
# 0    1.0
# 1    NaN
# 2    3.0
# dtype: float64

# %%
s.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
s.dropna()
# Out:
# 0    1.0
# 2    3.0
# dtype: float64

# %%
s.fillna(0)
# Out:
# 0    1.0
# 1    0.0
# 2    3.0
# dtype: float64

# %%
# Indexing

# %%
s = pd.Series([10,20,30,40,50],index=['a','b','c','d','e'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
s['a']
# Out:
# np.int64(10)

# %%
s['c']
# Out:
# np.int64(30)

# %%
# array

# %%
import numpy as np

# %%
a = np.array([2, 44.5, True, 'aryan'])

# %%
a
# Out:
# array(['2', '44.5', 'True', 'aryan'], dtype='<U32')
