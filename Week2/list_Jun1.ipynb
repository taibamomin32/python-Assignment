# %% [markdown]
# ### list

# %%
l = [23, 45, 67 ,89, 12]

# %%
print(l)
# Out:
# [23, 45, 67, 89, 12]

# %%
# list are hetero and duplicates are allowed

# %%
l1 = [23, 45, 67.90 ,89, 12, "python", "java", 23, 45]

# %%
l1
# Out:
# [23, 45, 67.9, 89, 12, 'python', 'java', 23, 45]

# %%
# lists are ordered

# %%
l1
# Out:
# [23, 45, 67.9, 89, 12, 'python', 'java', 23, 45]

# %%
l1[2]
# Out:
# 67.9

# %%
l1[-3]
# Out:
# 'java'

# %%
# lists are mutable

# %%
l1[1] = 100

# %%
l1
# Out:
# [23, 100, 67.9, 89, 12, 'python', 'java', 23, 45]

# %%
l1[-3] = True

# %%
l1
# Out:
# [23, 100, 67.9, 89, 12, 'python', True, 23, 45]

# %%
# list slicing

# %%
l = [21, 23, 45, 67 ,89, 11]

# %%
l
# Out:
# [21, 23, 45, 67, 89, 11]

# %%
l[1:4]
# Out:
# [23, 45, 67]

# %%
l[1:-2]
# Out:
# [23, 45, 67]

# %%
# 21, 45, 89

# %%
l[0:6:2]
# Out:
# [21, 45, 89]

# %%
l[::2]
# Out:
# [21, 45, 89]

# %%
# reverse the list

# %%
l
# Out:
# [21, 23, 45, 67, 89, 11]

# %%
l[::1]
# Out:
# [21, 23, 45, 67, 89, 11]

# %%
l[::-1]
# Out:
# [11, 89, 67, 45, 23, 21]

# %%
l
# Out:
# [21, 23, 45, 67, 89, 11]

# %%
l[1:4] = [100, 200, 300]

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
l1 = [12, 34, 56, 23]

# %%
del l1[-2]

# %%
l1
# Out:
# [12, 34, 23]

# %%
del l1

# %%
l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 l1
#
# NameError: name 'l1' is not defined

# %%
# membership operator

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
89 in l
# Out:
# True

# %%
1038 in l
# Out:
# False

# %%
# arithmetic operators

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
'ok' * 3 # string repetition
# Out:
# 'okokok'

# %%
l * 2 # repetition of list
# Out:
# [21, 100, 200, 300, 89, 11, 21, 100, 200, 300, 89, 11]

# %%
l + [60, 70, 80] # concatenation of list
# Out:
# [21, 100, 200, 300, 89, 11, 60, 70, 80]

# %%
# take 2 different list and add them

# %%
# iteration over list

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
# ierate over list and print square of each element

# %%
for i in l:
    print(i**2, end = ' ')
# Out:
# 441 10000 40000 90000 7921 121

# %%
# print odd number in the list

# %%
for i in l:
    if i % 2 == 1:
        print(i, end = ' ')
# Out:
# 21 89 11

# %%
# list comprehension -> [expression for_loop if_condition]

# %%
newl = [i**2 for i in l]
newl
# Out:
# [441, 10000, 40000, 90000, 7921, 121]

# %%
newl2 = [i for i in l if i % 2 == 1]

# %%
newl2
# Out:
# [21, 89, 11]

# %%
names = ['Aryan', 'atharv', 'sammruddhi', 'swaraj', 'Sukanya', 'shivraj']

# %%
names
# Out:
# ['Aryan', 'atharv', 'sammruddhi', 'swaraj', 'Sukanya', 'shivraj']

# %%
# create a new list with names which starts with 's' or 'S'

# %%
for i in names:
    if i.lower().startswith('s'):
        print(i)
# Out:
# sammruddhi
# swaraj
# Sukanya
# shivraj

# %%
new = [i for i in names if i.lower().startswith('s')]
new
# Out:
# ['sammruddhi', 'swaraj', 'Sukanya', 'shivraj']

# %%
for i in names:
    if i[0] == 's' or i[0] == 'S':
        print(i)
# Out:
# sammruddhi
# swaraj
# Sukanya
# shivraj

# %%
# functions

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
len(l)
# Out:
# 6

# %%
max(l)
# Out:
# 300

# %%
min(l)
# Out:
# 11

# %%
sorted(l)
# Out:
# [11, 21, 89, 100, 200, 300]

# %%
sorted(l, reverse = True)
# Out:
# [300, 200, 100, 89, 21, 11]

# %%
# list methods

# %%
# append

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
l.append(1000)

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11, 1000]

# %%
l1 = [1, 2, 3]
l2 = [1, 2, 3]

# %%
l1.append([100, 200])
l2.extend([100, 200])

# %%
l1
# Out:
# [1, 2, 3, [100, 200]]

# %%
l2
# Out:
# [1, 2, 3, 100, 200]

# %%
l1[3]
# Out:
# [100, 200]

# %%
l1[3][1]
# Out:
# 200

# %%
l1[3][1] = 37251289
l1
# Out:
# [1, 2, 3, [100, 37251289]]

# %%
# insert

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11, 1000]

# %%
l.insert(1, 78)
l
# Out:
# [21, 78, 100, 200, 300, 89, 11, 1000]

# %%
l.remove(78)

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11, 1000]

# %%
# pop

# %%
l.pop()
# Out:
# 1000

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
l.pop(3)
# Out:
# 300

# %%
l
# Out:
# [21, 100, 200, 89, 11]

# %%
l.index(89)
# Out:
# 3

# %%
l.sort(reverse = True)
l
# Out:
# [200, 100, 89, 21, 11]

# %%
l
# Out:
# [200, 100, 89, 21, 11]

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']
