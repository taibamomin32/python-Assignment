# %%
# exception/error handling

# %%
f = open('all.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 f = open('all.txt')
#
# File ~/anaconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'all.txt'

# %%
# try and except

# %%
try:
    f = open('all.txt')
except:
    print("file does not exist")
# Out:
# file does not exist

# %%
try:
    f = open('a1.txt')
    print(var1)
except:
    print("file does not exist")
# Out:
# file does not exist

# %%
# we need to be specific about what kind of error we want to catch

# %%
try:
    f = open('a1.txt')
    print(var1)
except FileNotFoundError:
    print("file does not exist")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 try:
#       2     f = open('a1.txt')
# ----> 3     print(var1)
#       4 except FileNotFoundError:
#       5     print("file does not exist")
#
# NameError: name 'var1' is not defined

# %%
try:
    f = open('a1.txt')
    print(var1)
except FileNotFoundError:
    print("file does not exist")
except Exception:
    print("something went wrong")
# Out:
# something went wrong

# %%
try:
    f = open('a1.txt')
    print(var1)
except FileNotFoundError:
    print("file does not exist")
except Exception as e:
    print(e)
# Out:
# name 'var1' is not defined

# %%
# else -> if try block doesnt raise any exception this will run

# %%
try:
    f = open('a1.txt')
except FileNotFoundError:
    print("file does not exist")
except Exception as e:
    print(e)
else:
    print(f.read())
    f.close()
# Out:
# this is the first line

# %%
# finally

# %%
try:
    f = open('a1.txt')
    print(var1)
except FileNotFoundError:
    print("file does not exist")
except Exception as e:
    print(e)
else:
    print(f.read())
    f.close()
finally:
    print("run complete")
# Out:
# name 'var1' is not defined
# run complete

# %%
# manually raise a exception

# %%
try:
    f = open('a1.txt')
    if f.name == 'a1.txt':
        raise Exception
except FileNotFoundError:
    print("file does not exist")
except Exception as e:
    print(e)
else:
    print(f.read())
    f.close()
finally:
    print("run complete")
# Out:
# run complete

# %%
f = open('a1.txt')
if f.name == 'a1.txt':
    raise Exception
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 f = open('a1.txt')
#       2 if f.name == 'a1.txt':
# ----> 3     raise Exception
#
# Exception:

# %%
# take 2 numbers as user input
# write a program for division of these 2 numbers
# handle ZeroDivisionError and ValueError
